# %%
from neuron.filters.convolve import convolve

# %%
import nibabel as nib
from matplotlib import pyplot as plt

# %%
img = nib.load('/home/hamlet/Programacion/C++/OpenCV/T1.nii.gz')

# %%
img_data = img.get_fdata()

# %%
plt.imshow(img_data[:,90,:], cmap=plt.cm.gray)

# %%
conv_img = convolve(img_data, 3)

# %%
plt.imshow(conv_img[:,90,:], cmap=plt.cm.gray)
